# %%
import numpy as np
import matplotlib.pyplot as plt

ca = np.array(np.fromfile('./losses/ca.bin'))
ga = np.array(np.fromfile('./losses/ca.bin'))
pso = np.array(np.fromfile('./losses/pso.bin'))
aco = np.array(np.fromfile('./losses/aco.bin'))

# %%
len(ca),len(ga),len(pso),len(aco)
# Out:
# (5000, 5000, 1000, 1000)

# %%
# plt.clf()
plt.plot(ca[::5],lw=5)
plt.plot(ga[::5])
plt.plot(pso)
plt.plot(aco)
plt.legend(['Cultural','Genetic','PSO','ACO'])
plt.ylim(0,2)
plt.savefig("./figs/f1.png")
